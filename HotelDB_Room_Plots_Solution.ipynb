# %% [markdown]
# <a href="https://colab.research.google.com/github/jpandersen61/MySQLNotebooks/blob/main/HotelDB_Room_Plots_Solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Visning af hotelværelse data

# %% [markdown]
# Databasens struktur er vist i nedenstående ER-Diagram

# %% [markdown]
# ###ER-Diagram

# %% [markdown]
# ![HotelDB.drawio.png](data:image/png;base64,...)

# %% [markdown]
# ###Installér nødvendige komponenter og indfør diverse opsætninger

# %%
pip install mysql-connector-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.1/34.1 MB 22.2 MB/s eta 0:00:00
# ...

# %%
import mysql.connector
import pandas as pd

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ###Connect til MySQL hotel database

# %%
mydb = mysql.connector.connect(
  host="mysql15.unoeuro.com",
  user="jean_zealand_dk",
  password="n25hwtBx9mcEdbar3RGy",
  database="jean_zealand_dk_db_HotelDB"
)

# %% [markdown]
# ### Udtræk af date for hotelværelser

# %%
query = "SELECT Name, Room_No, Price,Types FROM DemoHotel LEFT JOIN DemoRoom ON DemoHotel.Hotel_No = DemoRoom.Hotel_No ORDER BY Price"
query_result = pd.read_sql(query,mydb)
query_result
# Out:
#              Name  Room_No  Price Types
# 0        Discount       21  100.0     S
# 1        Discount       11  100.0     S
# 2        Discount       11  150.0     S
# 3        The Pope       11  150.0     S
# 4        The Pope       12  150.0     S
# 5        The Pope       13  150.0     S
# 6         Scandic       14  150.0     S
# 7         Scandic       13  150.0     S
# 8         Scandic       12  150.0     S
# 9         Scandic       11  150.0     S
# 10       Discount        2  170.0     D
# 11       Discount        1  175.0     D
# 12     Lucky Star       12  180.0     S
# 13       Discount        2  180.0     D
# 14     Lucky Star       11  180.0     S
# 15       Prindsen       11  185.0     S
# 16        Scandic        4  200.0     D
# 17       The Pope        2  200.0     D
# 18       Discount       31  200.0     F
# 19        Scandic        3  200.0     D
# 20        Scandic        2  200.0     D
# 21        Scandic        1  200.0     D
# ...

# %% [markdown]
# Opgaver:
# 1.   Lav et søjlediagram, som for hver søjle viser, hvor mange værelser, det enkelte hotel har. Start med at oprette en kodecelle, kommando *+ Code*. I denne definerer du plottet vha. Python kode.
# 2.   Lav et søjlediagram, som viser værelsespriserne i stignede orden. Start med at oprette en kodecelle, kommando *+ Code*. I denne definerer du plottet vha. Python kode.

# %%
{
    query_result['Name']
    .value_counts()
    .plot(kind='bar',
          title='Number of rooms by Hotel',
          xlabel="Hotel navn",
          ylabel="Antal værelser" )
};

# %%
{
    query_result[['Price']]
    #.sort_values(by='Price',ascending=False)
    .plot(title="Curves for Start-ups",
          xlabel="Company index sorted on profit",
          ylabel="$",
          cmap='Dark2',
          style=["--",".-","-+","-*"]  )
};
